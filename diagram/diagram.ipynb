# %%
# !pip install git+https://github.com/stanleygu/tellurium.git > /dev/null
# !pip install git+https://github.com/biomodels/BIOMD0000000051.git > /dev/null

# %%
from tellurium.visualization import SBMLDiagram
import BIOMD0000000051 as m

# %%
diagram = SBMLDiagram(m.sbmlString, reactions={
    'shape': 'box',
#     'label': '', # Hiding reaction nodes
#     'width': 0.1,
#     'height': 0.1,
#     'fixedsize': True
}, reactants={
    'arrowhead': 'none'
}, modifiers={
    'arrowhead': 'odot'
})
diagram.draw(layout='dot')

# %%
print diagram.G.string()
# Out:
# digraph {
# 	graph [bb="0,0,2345,1350"];
# 	node [label="\N"];
# 	cpep	 [height="0.51389",
# 		label="Phosphoenol pyruvate",
# 		pos="702,1259",
# 		width="3.3611"];
# 	vpepCxylase	 [height="0.5",
# 		label="PEP carboxylase",
# 		pos="147,894",
# 		shape=box,
# 		width="1.7778"];
# 	cpep -> vpepCxylase	 [arrowhead=none,
# 		pos="628.44,1244.3 524.46,1221.3 347,1173.3 347,1113 347,1113 347,1113 347,1040 347,9\
# 71.54 269.61,931.76 211.11,911.46"];
# 	vPEP	 [height="0.5",
# 		label="PEP degradation",
# 		pos="814,1186",
# 		shape=box,
# 		width="1.8056"];
# 	cpep -> vPEP	 [arrowhead=none,
# 		pos="729.69,1241 746.92,1229.7 769,1215.3 786.24,1204.1"];
# 	vDAHPS	 [height="0.5",
# 		label="DAHP synthesis",
# 		pos="1372,310",
# 		shape=box,
# 		width="1.75"];
# 	cpep -> vDAHPS	 [arrowhead=none,
# 		pos="773.38,1244 935.79,1205.4 1319,1086 1319,821 1319,821 1319,821 1319,456 1319,414\
# .25 1322.4,402.73 1338,364 1343.1,351.26 1351.3,338.19 1358.3,328.1"];
# 	vSynth1	 [height="0.5",
# ...
