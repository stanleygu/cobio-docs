# %% [markdown]
# # Searching for biomodels by chemical species

# %%
from tellurium.widgets import SearchBySpeciesForm
form = SearchBySpeciesForm()

# %%
import BIOMD0000000051
import tellurium as te

rr = te.loadSBMLModel(BIOMD0000000051.sbmlString)
sim = rr.simulate(0, 2, 200)
te.plotWithLegend(rr, sim)
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc'>
