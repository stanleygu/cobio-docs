# %%
# !pip install git+https://github.com/stanleygu/tellurium.git
# !pip install git+https://github.com/biomodels/BIOMD0000000042.git
from tellurium.visualization import SBMLDiagram
# Out:
# Downloading/unpacking git+https://github.com/stanleygu/tellurium.git
#   Cloning https://github.com/stanleygu/tellurium.git to /tmp/pip-HHnbne-build
#   Running setup.py (path:/tmp/pip-HHnbne-build/setup.py) egg_info for package from git+https://github.com/stanleygu/tellurium.git
# ...
# Cleaning up...
# Downloading/unpacking git+https://github.com/biomodels/BIOMD0000000042.git
#   Cloning https://github.com/biomodels/BIOMD0000000042.git to /tmp/pip-LRamWg-build
#   Running setup.py (path:/tmp/pip-LRamWg-build/setup.py) egg_info for package from git+https://github.com/biomodels/BIOMD0000000042.git
#     /usr/lib/python2.7/distutils/dist.py:267: UserWarning: Unknown distribution option: 'maintainer_url'
#       warnings.warn(msg)
#
# ...
# Cleaning up...

# %%
import BIOMD0000000042 as m
diagram = SBMLDiagram(m.sbmlString, reactions={
    'shape': 'box',
#     'label': '', # Hiding reaction nodes
#     'width': 0.1,
#     'height': 0.1,
#     'fixedsize': True
}, reactants={
    'arrowhead': 'none{'
}, modifiers={
    'arrowhead': 'odot'
})
diagram.draw(layout='dot')
