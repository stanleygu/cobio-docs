# %% [markdown]
# # Some setup

# %%
# !pip install --upgrade simworker notebooktools
# !pip install celery redis six
import tellurium as te
import numpy as np
import matplotlib.pyplot as plt
import time
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
# Out:
# Downloading/unpacking simworker
#   Downloading simworker-0.0.8.tar.gz
#   Running setup.py (path:/home/user/.virtualenvs/localpy/build/simworker/setup.py) egg_info for package simworker
#     WARNING: '' not a valid package name; please use only.-separated package names in setup.py
#     WARNING: '' not a valid package name; please use only.-separated package names in setup.py
# Downloading/unpacking notebooktools
#   Downloading notebooktools-0.1.0.tar.gz
#   Running setup.py (path:/home/user/.virtualenvs/localpy/build/notebooktools/setup.py) egg_info for package notebooktools
# Installing collected packages: simworker, notebooktools
#   Running setup.py install for simworker
#     WARNING: '' not a valid package name; please use only.-separated package names in setup.py
#     WARNING: '' not a valid package name; please use only.-separated package names in setup.py
#   Running setup.py install for notebooktools
# Successfully installed simworker notebooktools
# Cleaning up...
# Downloading/unpacking celery
#   Downloading celery-3.1.16-py2.py3-none-any.whl (514kB):  12%  65kB
#   Downloading celery-3.1.16-py2.py3-none-any.whl (514kB):  31%  163kB
#   Downloading celery-3.1.16-py2.py3-none-any.whl (514kB):  75%  389kB
#   Downloading celery-3.1.16-py2.py3-none-any.whl (514kB): 514kB downloaded
# Downloading/unpacking redis
#   Downloading redis-2.10.3.tar.gz (86kB):  80%  69kB
#   Downloading redis-2.10.3.tar.gz (86kB):  85%  73kB
#   Downloading redis-2.10.3.tar.gz (86kB): 86kB downloaded
#   Running setup.py (path:/home/user/.virtualenvs/localpy/build/redis/setup.py) egg_info for package redis
#     warning: no previously-included files found matching '__pycache__'
#     warning: no previously-included files matching '*.pyc' found under directory 'tests'
# Downloading/unpacking six
#   Downloading six-1.8.0-py2.py3-none-any.whl
# Downloading/unpacking billiard>=3.3.0.18,<3.4 (from celery)
#   Downloading billiard-3.3.0.18.tar.gz (150kB):   2%  4.1kB
#   Downloading billiard-3.3.0.18.tar.gz (150kB):  21%  32kB
#   Downloading billiard-3.3.0.18.tar.gz (150kB):  54%  81kB
#   Downloading billiard-3.3.0.18.tar.gz (150kB):  73%  110kB
#   Downloading billiard-3.3.0.18.tar.gz (150kB): 150kB downloaded
#   Running setup.py (path:/home/user/.virtualenvs/localpy/build/billiard/setup.py) egg_info for package billiard
#     warning: no files found matching '*.py' under directory 'Lib'
# Requirement already satisfied (use --upgrade to upgrade): pytz>dev in /usr/lib/python2.7/dist-packages (from celery)
# Downloading/unpacking kombu>=3.0.23,<3.1 (from celery)
#   Downloading kombu-3.0.23-py2.py3-none-any.whl (207kB):  15%  32kB
#   Downloading kombu-3.0.23-py2.py3-none-any.whl (207kB):  37%  77kB
#   Downloading kombu-3.0.23-py2.py3-none-any.whl (207kB):  71%  147kB
#   Downloading kombu-3.0.23-py2.py3-none-any.whl (207kB):  98%  204kB
#   Downloading kombu-3.0.23-py2.py3-none-any.whl (207kB): 207kB downloaded
# Downloading/unpacking amqp>=1.4.5,<2.0 (from kombu>=3.0.23,<3.1->celery)
#   Downloading amqp-1.4.6-py2-none-any.whl (49kB): 49kB downloaded
# Downloading/unpacking anyjson>=0.3.3 (from kombu>=3.0.23,<3.1->celery)
#   Downloading anyjson-0.3.3.tar.gz
#   Running setup.py (path:/home/user/.virtualenvs/localpy/build/anyjson/setup.py) egg_info for package anyjson
# Installing collected packages: celery, redis, six, billiard, kombu, amqp, anyjson
#   Running setup.py install for redis
#     warning: no previously-included files found matching '__pycache__'
#     warning: no previously-included files matching '*.pyc' found under directory 'tests'
#   Running setup.py install for billiard
#     building '_billiard' extension
#     gcc -pthread -fno-strict-aliasing -DNDEBUG -g -fwrapv -O2 -Wall -Wstrict-prototypes -fPIC -DHAVE_SEM_OPEN=1 -DHAVE_FD_TRANSFER=1 -DHAVE_SEM_TIMEDWAIT=1 -IModules/_billiard -I/usr/include/python2.7 -c Modules/_billiard/multiprocessing.c -o build/temp.linux-x86_64-2.7/Modules/_billiard/multiprocessing.o
#     gcc -pthread -fno-strict-aliasing -DNDEBUG -g -fwrapv -O2 -Wall -Wstrict-prototypes -fPIC -DHAVE_SEM_OPEN=1 -DHAVE_FD_TRANSFER=1 -DHAVE_SEM_TIMEDWAIT=1 -IModules/_billiard -I/usr/include/python2.7 -c Modules/_billiard/socket_connection.c -o build/temp.linux-x86_64-2.7/Modules/_billiard/socket_connection.o
#     gcc -pthread -fno-strict-aliasing -DNDEBUG -g -fwrapv -O2 -Wall -Wstrict-prototypes -fPIC -DHAVE_SEM_OPEN=1 -DHAVE_FD_TRANSFER=1 -DHAVE_SEM_TIMEDWAIT=1 -IModules/_billiard -I/usr/include/python2.7 -c Modules/_billiard/semaphore.c -o build/temp.linux-x86_64-2.7/Modules/_billiard/semaphore.o
#     gcc -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -Wl,-z,relro build/temp.linux-x86_64-2.7/Modules/_billiard/multiprocessing.o build/temp.linux-x86_64-2.7/Modules/_billiard/socket_connection.o build/temp.linux-x86_64-2.7/Modules/_billiard/semaphore.o -lrt -o build/lib.linux-x86_64-2.7/_billiard.so
#     warning: no files found matching '*.py' under directory 'Lib'
#   Running setup.py install for anyjson
# Successfully installed celery redis six billiard kombu amqp anyjson
# Cleaning up...

# %% [markdown]
# # Now let's define a model we will be using in the following examples

# %%
model = '''
  #Reactions:
  J0:    -> S1;  J0_v0
  J1: S1 ->   ;  J1_k3*S1
  J2: S1 -> S2; (J2_k1*S1)*(1 + J2_c*S2^J2_q)
  J3: S2 ->   ;  J3_k2*S2

  # Species initializations:
  S1 = 0
  S2 = 1

  # Variable initializations:
  J0_v0 = 8
  J1_k3 = 1
  J2_k1 = 1
  J2_c  = 1
  J2_q  = 3
  J3_k2 = 5
'''

rr = te.loadAntimonyModel(model)
print rr.model.getGlobalParameterValues()

TIME_START = 0
TIME_END = 5
TIME_STEPS = 80

data = rr.simulate(TIME_START, TIME_END, TIME_STEPS)
c = np.copy(data) # need to copy results or else it gets changed later
te.plotArray(data)
sbml = rr.getSBML()
# Out:
# [ 8.  1.  1.  1.  3.  5.]

# %% [markdown]
# # Now from our model let's create some noisy "experimental" data

# %%
def makeNoise(results, mean=0, std=1):
    import numpy as np
    dim = results.shape
    numSpecies = dim[1] - 1
    numPoints = dim[0]
    noise = np.hstack([np.array([np.random.normal(mean, std, numPoints)]).T for s in range(numSpecies)])
    return noise

noise = makeNoise(c, std=0.2)
noisyResults = np.hstack((np.array([c[:, 0]]).T, c[:, 1:] + noise))
te.plotArray(noisyResults)
# Out:
# [<matplotlib.lines.Line2D at 0x3437d50>,
#  <matplotlib.lines.Line2D at 0x3437e50>]

# %% [markdown]
# # Now let's use an evolutionary algorithm to fit parameters
#
# ## First, a helper simulation method and a fitness function

# %%
def getSim(rr, params):
    rr.reset()
    rr.model.setGlobalParameterValues(params)
    return rr.simulate(TIME_START, TIME_END, TIME_STEPS)

def getFitness(obs):
    expected = noisyResults

    sumofsquares = 0
    for index, value in np.ndenumerate(obs):
            expectedValue = expected[index[0], index[1]]
            residual = (value - expectedValue)
            sumofsquares += residual ** 2

    return sumofsquares

# %%
MAX_GENS = 50
POPULATION = 50

# %%
import diffevolution
de = diffevolution.DiffEvolution(rr,
                   fitnessFcn=getFitness,
                   simFcn=getSim,
                   MAX_GENS=MAX_GENS,
                   POPULATION=POPULATION,
                   SAVE_RESULTS=True,
                   paramRangeDict={
                     'J0_v0': (8, 8), # Constrain a few variables to make this faster
                     'J1_k3': (1, 1),
                     'J2_k1': (1, 1),
                     #'J2_c': (1, 1),
                     #'J2_q': (3, 3),
                     #'J3_k2': (5, 5)
                   })
de.start()
de.plotFitnesses()
de.plotBest(observed=noisyResults)
# Out:
# Finished after 16.540553093 seconds
# with population of 50 and 50 generations
# Best fitness value of 13.4146536019
# Best parameters of [8.0, 1.0, 1.0, 1.516588632370512, 3.0711078194151575, 6.022006300047188]

# %% [markdown]
# # Plotting correlations between fitted parameters

# %%
def plotCorrelations(
    pInds, members,
    labels=None
):
    import matplotlib.pyplot as mplot
    import numpy as np

    f, axarr = mplot.subplots(
        len(pInds),
        len(pInds))

    for i, p1 in enumerate(pInds):
        for j, p2 in enumerate(pInds):
            k1 = np.array([m.params[p1] for m in members])
            k2 = np.array([m.params[p2] for m in members])

            axarr[i, j].scatter(
                k1,
                k2)
            
            if labels is not None:
                p1_label = labels[p1]
                p2_label = labels[p2]
            else:
                p1_label = str(p1)
                p2_label = str(p2)

            if (i == len(pInds) - 1):
                axarr[i, j].set_xlabel('%s' % (p2_label))
            if (j is 0):
                axarr[i, j].set_ylabel('%s' % (p1_label))

# %%
parameter_names = ['J0_v0', 'J1_k3', 'J2_k1', 'J2_q', 'J3_k2', 'J2_c']

fitnesses = []
members = []
for g in de.generations:
    for f, m in zip(g['fitness'], g['members']):
        if f < 40:
            fitnesses.append(f)
            members.append(m)

pInds = [3, 4, 5]

plotCorrelations(pInds, members, labels=parameter_names)

# %% [markdown]
# # Now let's run a distributed parameter fitting algorithm
#
# ## We will need to define slightly different simuation and fitness function helpers

# %%
expected = noisyResults
def asyncSim(rr, params):
    import tasks
    
    return tasks.rrChain.delay([
        ['load', sbml],
        ['reset'],
        [['model', 'setGlobalParameterValues'], params],
        ['simulate', TIME_START, TIME_END, TIME_STEPS]
    ])

def getAsyncFitness(obs):
    sumofsquares = 0
    for index, value in np.ndenumerate(obs):
        expectedValue = expected[index[0], index[1]]
        residual = (value - expectedValue)
        sumofsquares += residual ** 2
    return sumofsquares

# %%
import diffevolution
MAX_GENS = 50
POPULATION = 50
deAsync = diffevolution.DiffEvolution(rr,
                   fitnessFcn=getAsyncFitness,
                   simFcn=asyncSim,
                   ASYNC=True,
                   SAVE_RESULTS=True,
                   MAX_GENS=MAX_GENS,
                   POPULATION=POPULATION,
                   paramRangeDict={
                     'J0_v0': (8, 8),
                     'J1_k3': (1, 1),
                     'J2_k1': (1, 1),
                     #'J2_c': (1, 1),
                     #'J2_q': (3, 3),
                     #'J3_k2': (5, 5)
                   })
deAsync.start()
deAsync.plotFitnesses()
deAsync.plotBest(observed=noisyResults)
# Out:
# Finished after 43.4222309589 seconds
# with population of 50 and 50 generations
# Best fitness value of 36.5423306152
# Best parameters of [8.0, 1.0, 1.0, 1.64435135374275, 2.5603789555712844, 6.190636049722176]

# %%
parameter_names = ['J0_v0', 'J1_k3', 'J2_k1', 'J2_q', 'J3_k2', 'J2_c']

fitnesses = []
members = []
for g in deAsync.generations:
    for f, m in zip(g['fitness'], g['members']):
        if f < 40:
            fitnesses.append(f)
            members.append(m)

pInds = [3, 4, 5]

plotCorrelations(pInds, members, labels=parameter_names)

# %% [markdown]
# # Notice that the distributed parameter fit took longer? How could this happen? Let's investigate
#
# ### First let's time how long it takes to do a simple add calculation

# %%
import tasks
import time
start = time.time()
tasks.add.delay(2, 2).get()
end = time.time()
print '%s seconds' % str(end-start)
# Out:
# 0.508666992188 seconds

# %% [markdown]
# There is some overhead in sending jobs and reading results. In our set up, there is also 0.5s rate limit on polling results.
#
# As you do more jobs, the amount of overhead per job lessens

# %%
import time
start = time.time()
numTrials = 30
asyncQueue = []
for i in range(numTrials):
    asyncQueue.append(tasks.add.delay(2, 2))
for job in asyncQueue:
    job.get()
end = time.time()
print '%s seconds' % str(end-start)
print '%s seconds per job' % str((end-start)/ numTrials)
# Out:
# 0.607491970062 seconds
# 0.0202497323354 seconds per job

# %%
# A slightly different method of calling many jobs, this is less performant for some reason
from celery import group
import time
start = time.time()
numTrials = 30
asyncQueue = []
for i in range(numTrials):
    asyncQueue.append(tasks.add.s(2, 2))

result = group(asyncQueue).apply_async()
print result.get()
end = time.time()
print '%s seconds' % str(end-start)
print '%s seconds per job' % str((end-start)/ numTrials)
# Out:
# [4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4]
# 1.07771110535 seconds
# 0.0359237035116 seconds per job

# %% [markdown]
# # Now let's compare some simulations

# %%
TIME_END = 100
NUM_SIMS = 300
import time
start = time.time()
asyncQueue = []
for i in range(NUM_SIMS):
    asyncQueue.append(tasks.rrChain.apply_async(
        ([['load', sbml],
          ['reset'],
          ['simulate', 0, TIME_END, 100]], ),
        serializer='json', compression='zlib'))

for job in asyncQueue:
    job.ready()
    job.get()
end = time.time()
print '%s seconds' % str(end-start)
print '%s seconds/sim' % str((end-start)/NUM_SIMS)
# Out:
# 1.45773887634 seconds
# 0.00485912958781 seconds/sim

# %%
import time
start = time.time()
for i in range(NUM_SIMS):
    #rr.load(sbml)
    rr.reset()
    rr.simulate(0, TIME_END, 100)
end = time.time()
print '%s seconds' % str(end-start)
print '%s seconds/sim' % str((end-start)/NUM_SIMS)
# Out:
# 9.99557089806 seconds
# 0.0333185696602 seconds/sim

# %% [markdown]
# # For this case, it looks like the time it takes for a job to be sent and the results retrieved is longer than a single simulation
#
# # What if each simulation took more time to complete?

# %%
TIME_END = 1000
NUM_SIMS = 300
import time
start = time.time()
asyncQueue = []
for i in range(NUM_SIMS):
    asyncQueue.append(tasks.rrChain.apply_async(
        ([['load', sbml],
          ['reset'],
          ['simulate', 0, TIME_END, 100]], ),
        serializer='json', compression='zlib'))

for job in asyncQueue:
    job.get()
end = time.time()
print '%s seconds' % str(end-start)
print '%s seconds/sim' % str((end-start)/NUM_SIMS)
# Out:
# 4.35613894463 seconds
# 0.0145204631488 seconds/sim

# %%
import time
start = time.time()
for i in range(NUM_SIMS):
    #rr.load(sbml)
    rr.reset()
    rr.simulate(0, TIME_END, 100)
end = time.time()
print '%s seconds' % str(end-start)
print '%s seconds/sim' % str((end-start)/NUM_SIMS)
# Out:
# 99.0915868282 seconds
# 0.330305289427 seconds/sim
